# %% [markdown]
# <a href="https://colab.research.google.com/github/marcory-hub/Seeed_Grove_Vision_AI_Module_V2/blob/main/YOLO_pt_to_vela_2026_02_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # int8 to vela for grove vision ai v2
#
# ## IMPORTANT: Use runtime 2025.07!
#
# Last accessed: 2026-06-05 top-view model
#
#
# - Put dataset and best.pt in root of google drive
# - Default: no_post=False
#
# Click [here](https://github.com/HimaxWiseEyePlus/YOLO11_on_WE2?tab=readme-ov-file#open-yolo11_on_we2_tutorialipynb-on-colab) for the himax wise eye plus repository. Currently only support YOLO11 object detection task.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Copy zipped dataset to colab
# !cp '/content/drive/MyDrive/dataset.zip' '/content/dataset.zip'

# Unzip quietly to avoid massive logs (remove -q -n flags if needed)
# -q = quiet (no file list output)
# -n = no overwrite (skips existing files)
# !unzip -qn '/content/dataset.zip' -d '/content/dataset/'

# Copy model weights
# !cp '/content/drive/MyDrive/best.pt' '/content/best.pt'

# %%
# !pip install -q onnx==1.17.0 onnxruntime==1.26.0 tensorflow==2.18.0

# %%
# Make a calibrationset with seed 42
import os
import random
import shutil

# Configuration
nc = "4"
class_names = "'amel', 'vcra', 'vespsp', 'vvel'"
num_images = 500
original_train_dir = "/content/dataset/train"
original_valid_dir = "/content/dataset/val"
temp_dir = "/content/temp_subset"

# Set seed for reproducibility
random.seed(42)

# Clean up existing temp folder to ensure a fresh start
if os.path.exists(temp_dir):
    shutil.rmtree(temp_dir)
    print(f"Cleaned up existing directory: {temp_dir}")

def copy_random_subset(src_dir, dst_dir, num_images):
    # Get all valid image files
    img_path = f"{src_dir}/images"
    if not os.path.exists(img_path):
        print(f"Warning: {img_path} not found. Skipping.")
        return 0

    all_images = [f for f in os.listdir(img_path)
                  if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

    # Randomly sample
    selected = random.sample(all_images, min(num_images, len(all_images)))

    os.makedirs(f"{dst_dir}/images", exist_ok=True)
    os.makedirs(f"{dst_dir}/labels", exist_ok=True)

    count = 0
    for img in selected:
        label = img.rsplit('.', 1)[0] + '.txt'

        # Copy image
        shutil.copy(f"{src_dir}/images/{img}", f"{dst_dir}/images/{img}")

        # Copy label if it exists (null images handled here)
        src_label_path = f"{src_dir}/labels/{label}"
        if os.path.exists(src_label_path):
            shutil.copy(src_label_path, f"{dst_dir}/labels/{label}")
        count += 1
    return count

# Execute copying
train_count = copy_random_subset(original_train_dir, f"{temp_dir}/train", num_images)
valid_count = copy_random_subset(original_valid_dir, f"{temp_dir}/valid", num_images)

# Prepare YAML data
nc_int = int(nc)
names_list = [name.strip().strip("'") for name in class_names.split(',')]

temp_data_string = f"""
train: {temp_dir}/train/images
val: {temp_dir}/valid/images
nc: {nc_int}
names: {names_list}
"""

# Write the new YAML file
with open("/content/dataset/data.yaml", 'w') as f:
    f.write(temp_data_string.strip())

print("--- Summary ---")
print(f"Train images sampled: {train_count}")
print(f"Valid images sampled: {valid_count}")
print(f"YAML created at: /content/temp_data.yaml")
# Out:
# Cleaned up existing directory: /content/temp_subset
# --- Summary ---
# Train images sampled: 500
# Valid images sampled: 500
# YAML created at: /content/temp_data.yaml

# %% [markdown]
# # 0.a export original yolo11n int8 tflite with BatchMatMul Operater

# %%
# !git clone https://github.com/kris-himax/ultralytics
# %cd ultralytics
# %pip install .
# %cd ..
import ultralytics
ultralytics.checks()
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
# /content/ultralytics
# ^C

# %%
# Export the YOLO model to INT8 TFLite format
# Default no_post=False, change to True if needed
# !yolo export \
    model='best.pt' \
    format='tflite' \
    int8=True \
    no_post=True \
    imgsz=224 \
    data='dataset/data.yaml'
# Out:
# Ultralytics 8.3.53 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 239 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) ((1, 68, 28, 28), (1, 68, 14, 14), (1, 68, 7, 7)) (5.2 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780688995.645214   10069 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780688995.652447   10069 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.94...
# ONNX: export success ✅ 3.8s, saved as 'best.onnx' (10.0 MB)
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=dataset/data.yaml'
# Scanning /content/temp_subset/valid/labels.cache... 500 images, 38 backgrounds, 0 corrupt: 100% 500/500 [00:00<?, ?it/s]
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.22.3...
# I0000 00:00:1780689059.162358   10069 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780689059.162664   10069 single_machine.cc:361] Starting new session
# W0000 00:00:1780689062.184946   10069 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1780689062.185028   10069 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1780689063.603479   10069 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# I0000 00:00:1780689063.603765   10069 single_machine.cc:361] Starting new session
# W0000 00:00:1780689067.737479   10069 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1780689067.737525   10069 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1780689070.082119   10069 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# I0000 00:00:1780689070.082332   10069 single_machine.cc:361] Starting new session
# W0000 00:00:1780689072.807916   10069 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1780689072.807990   10069 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# W0000 00:00:1780689100.722155   10069 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1780689100.722199   10069 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1780689100.790577   10069 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# W0000 00:00:1780689207.084390   10069 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1780689207.084451   10069 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# W0000 00:00:1780689312.685626   10069 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1780689312.685714   10069 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# W0000 00:00:1780689510.618241   10069 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1780689510.618318   10069 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# TensorFlow SavedModel: export success ✅ 702.2s, saved as 'best_saved_model' (34.5 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.18.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as 'best_saved_model/best_int8.tflite' (2.6 MB)
#
# Export complete (702.5s)
# Results saved to /content
# Predict:         yolo predict task=detect model=best_saved_model/best_int8.tflite imgsz=224 int8
# Validate:        yolo val task=detect model=best_saved_model/best_int8.tflite imgsz=224 data=/content/dataset/data.yaml int8
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# # Install vela compiler

# %%
# Install the Arm Ethos-U Vela compiler
# !pip3 install ethos-u-vela

# Download the specific Himax configuration for the Grove Vision AI V2
# !wget https://raw.githubusercontent.com/HimaxWiseEyePlus/ML_FVP_EVALUATION/main/vela/himax_vela.ini
# Out:
# Requirement already satisfied: ethos-u-vela in /usr/local/lib/python3.11/dist-packages (5.1.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from ethos-u-vela) (25.2.10)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ethos-u-vela) (2.0.2)
# --2026-06-05 20:01:58--  https://raw.githubusercontent.com/HimaxWiseEyePlus/ML_FVP_EVALUATION/main/vela/himax_vela.ini
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 889 [text/plain]
# Saving to: ‘himax_vela.ini.1’
#
# himax_vela.ini.1    100%[===================>]     889  --.-KB/s    in 0s
#
# 2026-06-05 20:01:58 (45.2 MB/s) - ‘himax_vela.ini.1’ saved [889/889]

# %% [markdown]
# # Convert yolo11 int8 tflite to vela model

# %%
# Compile the model for the Ethos-U55 NPU (64 MAC configuration)
# !vela --accelerator-config ethos-u55-64 \
    --config himax_vela.ini \
    --system-config My_Sys_Cfg \
    --memory-mode My_Mem_Mode_Parent \
    --output-dir ./best_saved_model \
    ./best_saved_model/best_full_integer_quant.tflite
# Out:
# Network summary for best_full_integer_quant
# Accelerator configuration                Ethos_U55_64
# System configuration                       My_Sys_Cfg
# Memory mode                        My_Mem_Mode_Parent
# Accelerator clock                                 400 MHz
# Design peak SRAM bandwidth                       2.98 GB/s
# Design peak Off-chip Flash bandwidth             0.05 GB/s
#
# Total SRAM used                                923.84 KiB
# Total Off-chip Flash used                     1941.06 KiB
#
# CPU operators = 0 (0.0%)
# NPU operators = 455 (100.0%)
#
# Average SRAM bandwidth                           0.69 GB/s
# Input   SRAM bandwidth                          17.79 MB/batch
# Weight  SRAM bandwidth                          10.04 MB/batch
# Output  SRAM bandwidth                           7.93 MB/batch
# Total   SRAM bandwidth                          36.36 MB/batch
# Total   SRAM bandwidth            per input     36.36 MB/inference (batch size 1)
#
# Average Off-chip Flash bandwidth                 0.04 GB/s
# Input   Off-chip Flash bandwidth                 0.01 MB/batch
# Weight  Off-chip Flash bandwidth                 1.87 MB/batch
# Output  Off-chip Flash bandwidth                 0.00 MB/batch
# Total   Off-chip Flash bandwidth                 1.90 MB/batch
# Total   Off-chip Flash bandwidth  per input      1.90 MB/inference (batch size 1)
#
# Neural network macs                         390200132 MACs/batch

# %% [markdown]
# # Check if vela model size

# %%
import os

# Updated path to the specific location of your Vela model
output_model = '/content/best_saved_model/best_full_integer_quant_vela.tflite'

def check_model(path, name):
    if os.path.exists(path):
        size_mb = os.path.getsize(path) / (1024 * 1024)
        print(f"{name} Path: {path}")
        print(f"{name} Size: {size_mb:.2f} MB")
        return size_mb
    else:
        print(f"⚠️ {name} not found at: {path}")
        return None

# Check the size
final_size = check_model(output_model, "Vela Optimized Model")

# Grove Vision AI V2 Constraint Check
if final_size:
    LIMIT = 2.4
    if final_size <= LIMIT:
        print(f"✅ SUCCESS: Model is within the {LIMIT}MB limit.")
    else:
        print(f"❌ ERROR: Model ({final_size:.2f}MB) exceeds the {LIMIT}MB limit!")
        print("Tip: If it's too large, reduce 'imgsz' during export or use a smaller architecture.")
# Out:
# Vela Optimized Model Path: /content/best_saved_model/best_full_integer_quant_vela.tflite
# Vela Optimized Model Size: 1.97 MB
# ✅ SUCCESS: Model is within the 2.4MB limit.

# %% [markdown]
# # Compare metrics of best.pt and int8.tflite

# %%
from ultralytics import YOLO
import pandas as pd

# Define paths
DATA_YAML = '/content/dataset/data.yaml'
PT_MODEL_PATH = '/content/best.pt'
TFLITE_MODEL_PATH = '/content/best_saved_model/best_full_integer_quant.tflite'

# 1. Validate PyTorch Model (The Baseline)
print("Evaluating PyTorch Model...")
model_pt = YOLO(PT_MODEL_PATH)
results_pt = model_pt.val(data=DATA_YAML, split='test', imgsz=224, verbose=False)

# 2. Validate TFLite Model (The Quantized Version)
print("Evaluating INT8 TFLite Model...")
model_tflite = YOLO(TFLITE_MODEL_PATH, task='detect')
results_tflite = model_tflite.val(data=DATA_YAML, split='test', imgsz=224, verbose=False, batch=1)

# 3. Create Comparison Table
data = {
    "Metric": ["mAP@50", "mAP@50-95", "Precision", "Recall"],
    "PyTorch (FP32)": [
        results_pt.box.map50,
        results_pt.box.map,
        results_pt.box.mp,
        results_pt.box.mr
    ],
    "TFLite (INT8)": [
        results_tflite.box.map50,
        results_tflite.box.map,
        results_tflite.box.mp,
        results_tflite.box.mr
    ]
}

df = pd.DataFrame(data)
df['Loss (%)'] = ((df['PyTorch (FP32)'] - df['TFLite (INT8)']) / df['PyTorch (FP32)']) * 100
print("\n--- Model Accuracy Comparison ---")
print(df.to_string(index=False))
# Out:
# Evaluating PyTorch Model...
# Ultralytics 8.3.53 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 239 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ultralytics/data/base.py in get_img_files(self, img_path)
#     110             for p in img_path if isinstance(img_path, list) else [img_path]:
# --> 111                 p = Path(p)  # os-agnostic
#     112                 if p.is_dir():  # dir
#
# /usr/lib/python3.11/pathlib.py in __new__(cls, *args, **kwargs)
#     870             cls = WindowsPath if os.name == 'nt' else PosixPath
# --> 871         self = cls._from_parts(args)
#     872         if not self._flavour.is_supported:
#
# /usr/lib/python3.11/pathlib.py in _from_parts(cls, args)
#     508         self = object.__new__(cls)
# --> 509         drv, root, parts = self._parse_args(args)
#     510         self._drv = drv
#
# /usr/lib/python3.11/pathlib.py in _parse_args(cls, args)
#     492             else:
# --> 493                 a = os.fspath(a)
#     494                 if isinstance(a, str):
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-15-1593204073.py in <cell line: 0>()
#      10 print("Evaluating PyTorch Model...")
#      11 model_pt = YOLO(PT_MODEL_PATH)
# ---> 12 results_pt = model_pt.val(data=DATA_YAML, split='test', imgsz=224, verbose=False)
#      13
#      14 # 2. Validate TFLite Model (The Quantized Version)
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in val(self, validator, **kwargs)
#     637
#     638         validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 639         validator(model=self.model)
#     640         self.metrics = validator.metrics
#     641         return validator.metrics
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/validator.py in __call__(self, trainer, model)
#     154                 self.args.rect = False
#     155             self.stride = model.stride  # used in get_dataloader() for padding
# --> 156             self.dataloader = self.dataloader or self.get_dataloader(self.data.get(self.args.split), self.args.batch)
#     157
#     158             model.eval()
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/detect/val.py in get_dataloader(self, dataset_path, batch_size)
#     241     def get_dataloader(self, dataset_path, batch_size):
#     242         """Construct and return dataloader."""
# --> 243         dataset = self.build_dataset(dataset_path, batch=batch_size, mode="val")
#     244         return build_dataloader(dataset, batch_size, self.args.workers, shuffle=False, rank=-1)  # return dataloader
#     245
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/detect/val.py in build_dataset(self, img_path, mode, batch)
#     237             batch (int, optional): Size of batches, this is for `rect`. Defaults to None.
#     238         """
# --> 239         return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, stride=self.stride)
#     240
#     241     def get_dataloader(self, dataset_path, batch_size):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/data/build.py in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#      85     """Build YOLO Dataset."""
#      86     dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# ---> 87     return dataset(
#      88         img_path=img_path,
#      89         imgsz=cfg.imgsz,
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/data/dataset.py in __init__(self, data, task, *args, **kwargs)
#      62         self.data = data
#      63         assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 64         super().__init__(*args, **kwargs)
#      65
#      66     def cache_labels(self, path=Path("./labels.cache")):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/data/base.py in __init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction)
#      71         self.prefix = prefix
#      72         self.fraction = fraction
# ---> 73         self.im_files = self.get_img_files(self.img_path)
#      74         self.labels = self.get_labels()
#      75         self.update_labels(include_class=classes)  # single_cls and include_class
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/data/base.py in get_img_files(self, img_path)
#     125             assert im_files, f"{self.prefix}No images found in {img_path}. {FORMATS_HELP_MSG}"
#     126         except Exception as e:
# --> 127             raise FileNotFoundError(f"{self.prefix}Error loading data from {img_path}\n{HELP_URL}") from e
#     128         if self.fraction < 1:
#     129             im_files = im_files[: round(len(im_files) * self.fraction)]  # retain a fraction of the dataset
#
# FileNotFoundError: val: Error loading data from None
# See https://docs.ultralytics.com/datasets for dataset formatting guidance.

# %%
import shutil
import os
from ultralytics import YOLO

# 1. Load the TFLite model
model_path = '/content/best_saved_model/best_full_integer_quant.tflite'
model = YOLO(model_path, task='detect')

# 2. Run validation on the ALL images in the 'val' split
# We set 'project' to /content/ and 'name' to 'temp_val' to control the output folder
results = model.val(
    data='/content/dataset/data.yaml',
    split='val',
    imgsz=224,
    plots=True,
    batch=1,
    project='/content',
    name='temp_val_run'
)

# 3. Define source and destination
# YOLO saves results in project/name/ (e.g., /content/temp_val_run/)
source_dir = '/content/temp_val_run'
dest_folder = '/content/best_saved_model'

# 4. Copy the confusion matrix and other evaluation plots to best_saved_model
files_to_copy = ['confusion_matrix.png', 'confusion_matrix_normalized.png', 'results.png', 'PR_curve.png']

for file_name in files_to_copy:
    src_path = os.path.join(source_dir, file_name)
    if os.path.exists(src_path):
        shutil.copy(src_path, os.path.join(dest_folder, file_name))
        print(f"✅ Saved {file_name} to {dest_folder}")

# Clean up temporary folder
shutil.rmtree(source_dir)
# Out:
# Ultralytics 8.3.53 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Loading /content/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 224, 224)
# val: Scanning /content/temp_subset/valid/labels.cache... 500 images, 38 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/500 [00:00<?, ?it/s]Exception in thread Thread-14 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/utils/plotting.py", line 1115, in plot_images
#     annotator.box_label(box, label, color=color, rotated=is_obb)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/utils/plotting.py", line 356, in box_label
#     self.draw.rectangle(box, width=self.lw, outline=color)  # box
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/PIL/ImageDraw.py", line 410, in rectangle
#     self.draw.draw_rectangle(xy, ink, 0, width)
# ValueError: y1 must be greater than or equal to y0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 2/500 [00:00<01:11,  6.96it/s]Exception in thread Thread-16 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/utils/plotting.py", line 1115, in plot_images
#     annotator.box_label(box, label, color=color, rotated=is_obb)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/utils/plotting.py", line 356, in box_label
#     self.draw.rectangle(box, width=self.lw, outline=color)  # box
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/PIL/ImageDraw.py", line 410, in rectangle
#     self.draw.draw_rectangle(xy, ink, 0, width)
# ValueError: x1 must be greater than or equal to x0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   1%|          | 3/500 [00:00<01:13,  6.78it/s]Exception in thread Thread-18 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/utils/plotting.py", line 1115, in plot_images
#     annotator.box_label(box, label, color=color, rotated=is_obb)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/utils/plotting.py", line 356, in box_label
#     self.draw.rectangle(box, width=self.lw, outline=color)  # box
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/PIL/ImageDraw.py", line 410, in rectangle
#     self.draw.draw_rectangle(xy, ink, 0, width)
# ValueError: y1 must be greater than or equal to y0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 500/500 [00:17<00:00, 28.78it/s]
#                    all        500        515          0          0          0          0
# Speed: 0.3ms preprocess, 26.1ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /content/temp_val_run
# ✅ Saved confusion_matrix.png to /content/best_saved_model
# ✅ Saved confusion_matrix_normalized.png to /content/best_saved_model

# %% [markdown]
# # Zip and download the full_integer_quant_vela_imgz_224_nopost.tflite
# Add NOPOST before the . if needed

# %%
import shutil
import os
from google.colab import files

# Move best.onnx into the saved_model folder
source_onnx = '/content/best.onnx'
dest_folder = '/content/best_saved_model'

if os.path.exists(source_onnx):
    shutil.move(source_onnx, os.path.join(dest_folder, 'best.onnx'))
    print("Moved best.onnx to best_saved_model folder.")
else:
    print("best.onnx not found at root. It might already be moved.")

# Zip the best_saved_model folder
zip_name = 'full_integer_quant_vela_imgz224.tflite'
shutil.make_archive(zip_name, 'zip', dest_folder)
print(f"Created {zip_name}.zip")

# Download the zip file to your computer
files.download(f'{zip_name}.zip')
# Out:
# best.onnx not found at root. It might already be moved.
# Created full_integer_quant_vela_imgz224.tflite.zip
